# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from  scipy import stats
import  matplotlib
#指定默认字体  
matplotlib.rcParams['font.sans-serif'] = ['SimHei']   
matplotlib.rcParams['font.family']='sans-serif'  
#解决负号'-'显示为方块的问题  
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
path=r"TRD_Index.txt"

# %%
data=pd.read_table(path,sep="\t")
data
# Out:
#        Indexcd       Trddt  Daywk  Opnindex   Hiindex   Loindex  Clsindex  \
# 0            1  2009-01-05      1  1849.020  1880.716  1844.094  1880.716
# 1            1  2009-01-06      2  1878.827  1938.690  1871.971  1937.145
# 2            1  2009-01-07      3  1938.974  1948.233  1920.515  1924.012
# 3            1  2009-01-08      4  1890.242  1894.171  1862.263  1878.181
# 4            1  2009-01-09      5  1875.164  1909.349  1875.164  1904.861
# 5            1  2009-01-12      1  1897.703  1924.441  1886.833  1900.347
# 6            1  2009-01-13      2  1880.868  1888.309  1861.811  1863.367
# 7            1  2009-01-14      3  1862.310  1929.276  1862.309  1928.869
# 8            1  2009-01-15      4  1912.772  1937.728  1902.542  1920.206
# 9            1  2009-01-16      5  1928.922  1984.728  1928.922  1954.438
# 10           1  2009-01-19      1  1971.000  2018.510  1966.188  1986.672
# 11           1  2009-01-20      2  1981.147  1994.809  1956.102  1994.107
# ...

# %%
shanghaiIndex=data[data.Indexcd==1]
shanghaiIndex
# Out:
#       Indexcd       Trddt  Daywk  Opnindex   Hiindex   Loindex  Clsindex  \
# 0           1  2009-01-05      1  1849.020  1880.716  1844.094  1880.716
# 1           1  2009-01-06      2  1878.827  1938.690  1871.971  1937.145
# 2           1  2009-01-07      3  1938.974  1948.233  1920.515  1924.012
# 3           1  2009-01-08      4  1890.242  1894.171  1862.263  1878.181
# 4           1  2009-01-09      5  1875.164  1909.349  1875.164  1904.861
# 5           1  2009-01-12      1  1897.703  1924.441  1886.833  1900.347
# 6           1  2009-01-13      2  1880.868  1888.309  1861.811  1863.367
# 7           1  2009-01-14      3  1862.310  1929.276  1862.309  1928.869
# 8           1  2009-01-15      4  1912.772  1937.728  1902.542  1920.206
# 9           1  2009-01-16      5  1928.922  1984.728  1928.922  1954.438
# 10          1  2009-01-19      1  1971.000  2018.510  1966.188  1986.672
# 11          1  2009-01-20      2  1981.147  1994.809  1956.102  1994.107
# ...

# %%
shenzhenIndex=data[data.Indexcd==399106]
shenzhenIndex
# Out:
#        Indexcd       Trddt  Daywk  Opnindex   Hiindex   Loindex  Clsindex  \
# 13012   399106  2009-01-05      1   560.097   571.134   557.687   571.134
# 13013   399106  2009-01-06      2   569.278   587.676   566.723   586.332
# 13014   399106  2009-01-07      3   585.504   590.658   582.341   584.705
# 13015   399106  2009-01-08      4   573.940   577.834   567.622   573.093
# 13016   399106  2009-01-09      5   572.256   586.657   572.256   585.852
# 13017   399106  2009-01-12      1   584.455   596.649   583.085   588.723
# 13018   399106  2009-01-13      2   581.691   584.929   571.368   571.622
# 13019   399106  2009-01-14      3   570.201   594.015   570.201   594.015
# 13020   399106  2009-01-15      4   589.189   603.118   587.410   595.867
# 13021   399106  2009-01-16      5   598.536   609.447   598.536   600.689
# 13022   399106  2009-01-19      1   603.817   608.543   594.931   601.252
# 13023   399106  2009-01-20      2   599.890   606.813   596.226   606.813
# ...

# %%
plt.scatter(shanghaiIndex.Retindex,shenzhenIndex.Retindex) #绘制伞点
plt.xlabel("上海指数")
plt.ylabel("深圳指数")
plt.title("散点图")
plt.legend()

# %%
shenzhenIndex.index=shanghaiIndex.index #交换索引
shenzhenIndex.Retindex.corr(shanghaiIndex.Retindex) #计算平均斜率
# Out:
# 0.90827763480145474
