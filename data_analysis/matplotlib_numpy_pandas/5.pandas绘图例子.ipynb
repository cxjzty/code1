# %%
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
#指定默认字体  
matplotlib.rcParams['font.sans-serif'] = ['SimHei']   
matplotlib.rcParams['font.family']='sans-serif'  
#解决负号'-'显示为方块的问题  
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
path=r"userlose.xls"
userlose=pd.read_excel(path)
userlose
# Out:
#       客户编号    年龄  注册服务    在网时间  IP通话时间    消费积分  投诉次数  话费连续降低  不同呼叫次数  呼转金额  \
# 0   201201  37.0   4.0   361.0     9.0  2322.0   2.0    0.72     4.0  0.23
# 1   201202  28.0   5.0   789.0    37.0  4511.0   5.0    0.31    11.0  0.39
# 2   201203  62.0   6.0   239.0     8.0   478.0   1.0    0.03     5.0  0.16
# 3   201204  46.0   7.0   943.0     1.0  2370.0   3.0   -0.03     3.0  0.16
# 4   201205  31.0   3.0   936.0     4.0  5548.0   2.0    0.18    17.0  0.44
# 5   201206  25.0   4.0   872.0    26.0    16.0   4.0    0.05     5.0  0.32
# 6   201207  64.0   6.0    27.0     1.0   130.0   0.0    0.02    15.0  0.35
# 7   201208  16.0   7.0   753.0    31.0  2400.0   0.0    0.08    20.0  0.21
# 8   201209  61.0   3.0   129.0     3.0   487.0   4.0    0.72     1.0  0.08
# 9   201210  21.0   4.0   237.0     6.0  1837.0   3.0   -0.02     9.0  0.36
# 10  201211  32.0   5.0   312.0     3.0  2810.0   1.0    0.16     5.0  0.33
# ...

# %%
userlose["年龄"]
# Out:
# 0     37.0
# 1     28.0
# 2     62.0
# 3     46.0
# 4     31.0
# 5     25.0
# 6     64.0
# 7     16.0
# 8     61.0
# 9     21.0
# 10    32.0
# 11    23.0
# 12    48.0
# 13    25.0
# 14    32.0
# 15    40.0
# 16    51.0
# 17    61.0
# 18    43.0
# 19    30.0
# Name: 年龄, dtype: float64

# %%
age=userlose["年龄"]   #series  一维数组
type(age)
# Out:
# pandas.core.series.Series

# %%
age.plot()
plt.show()

# %%
type(userlose)
# Out:
# pandas.core.frame.DataFrame

# %%
userlose.plot()

# %%
plt.show()

# %%
userlose.plot(kind="kde")
plt.show()

# %%
userlose.plot(kind="bar")
plt.show()

# %%
userlose.plot(kind="bar",stacked=True)
plt.show()

# %%
userlose.plot(kind="barh",stacked=True)
plt.show()

# %%
userlose.plot(x="年龄",y="在网时间",kind="scatter")
plt.show()

# %%
userlose.boxplot()

# %%
plt.show()
