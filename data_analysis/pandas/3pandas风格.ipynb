# %%
import pandas as pd
# 使图表更大更漂亮
pd.set_option('display.mpl_style', 'default')  #默认的显示风格
pd.set_option('display.line_width', 5000) #一行最大宽度
pd.set_option('display.max_columns', 60)#最多有60列
# Out:
# c:\users\tsinghua-yincheng\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py:2910: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# line_width has been deprecated, use display.width instead (currently both are
# identical)

# %%
nasa=pd.read_table(r"C:\Users\Tsinghua-yincheng\Desktop\SZday72\nasa.txt")

# %%
nasa[1:1]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>会员ID</th>
#       <th>姓名</th>
#       <th>性别</th>
#       <th>年龄</th>
#       <th>身高</th>
#       <th>学历</th>
#       <th>婚否</th>
#       <th>所在地</th>
#       <th>星座</th>
#       <th>职业</th>
#       <th>语言</th>
#       <th>愿意/可能前往</th>
#       <th>服务收费/支付能力</th>
#       <th>伴游经验</th>
#       <th>服务内容/需求服务</th>
#       <th>伴游心情/其他说明</th>
#       <th>最方便联系时间</th>
#       <th>联系电话</th>
#       <th>Email</th>
#       <th>博客</th>
#       <th>QQ</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
nasa[1:2]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>会员ID</th>
#       <th>姓名</th>
#       <th>性别</th>
#       <th>年龄</th>
#       <th>身高</th>
#       <th>学历</th>
#       <th>婚否</th>
#       <th>所在地</th>
#       <th>星座</th>
#       <th>职业</th>
#       <th>语言</th>
#       <th>愿意/可能前往</th>
#       <th>服务收费/支付能力</th>
#       <th>伴游经验</th>
#       <th>服务内容/需求服务</th>
#       <th>伴游心情/其他说明</th>
#       <th>最方便联系时间</th>
#       <th>联系电话</th>
#       <th>Email</th>
#       <th>博客</th>
#       <th>QQ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>88548</td>
#       <td>n小姐</td>
#       <td>女</td>
#       <td>22</td>
#       <td>162</td>
# ...

# %%
nasa[1:2] #只能按照M-N之间，不可以按照数组的索引
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>会员ID</th>
#       <th>姓名</th>
#       <th>性别</th>
#       <th>年龄</th>
#       <th>身高</th>
#       <th>学历</th>
#       <th>婚否</th>
#       <th>所在地</th>
#       <th>星座</th>
#       <th>职业</th>
#       <th>语言</th>
#       <th>愿意/可能前往</th>
#       <th>服务收费/支付能力</th>
#       <th>伴游经验</th>
#       <th>服务内容/需求服务</th>
#       <th>伴游心情/其他说明</th>
#       <th>最方便联系时间</th>
#       <th>联系电话</th>
#       <th>Email</th>
#       <th>博客</th>
#       <th>QQ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>88548</td>
#       <td>n小姐</td>
#       <td>女</td>
#       <td>22</td>
#       <td>162</td>
# ...

# %%
type(nasa)
# Out:
# pandas.core.frame.DataFrame

# %%
import tushare as ts
stock=ts.get_hist_data('600848') #一次性获取全部日k线数据
stock
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#       <th>volume</th>
#       <th>price_change</th>
#       <th>p_change</th>
#       <th>ma5</th>
#       <th>ma10</th>
#       <th>ma20</th>
#       <th>v_ma5</th>
#       <th>v_ma10</th>
#       <th>v_ma20</th>
#       <th>turnover</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
# ...

# %%
stock["high"] #取出列
# Out:
# date
# 2017-11-28    24.90
# 2017-11-27    24.95
# 2017-11-24    24.70
# 2017-11-23    25.43
# 2017-11-22    25.90
# 2017-11-21    25.98
# 2017-11-20    25.58
# 2017-11-17    28.15
# 2017-11-16    28.72
# 2017-11-15    29.30
# 2017-11-14    29.89
# 2017-11-13    29.23
# 2017-11-10    28.99
# 2017-11-09    29.09
# 2017-11-08    29.70
# 2017-11-07    29.37
# 2017-11-06    28.74
# 2017-11-03    29.62
# 2017-11-02    31.80
# 2017-11-01    34.34
# 2017-10-31    35.22
# 2017-10-30    34.40
# 2017-10-27    33.20
# 2017-10-26    32.70
# 2017-10-25    30.45
# 2017-10-24    28.75
# 2017-10-23    31.16
# 2017-10-20    29.83
# 2017-10-19    27.20
# 2017-10-18    26.41
#               ...
# 2015-01-20    11.13
# 2015-01-19    11.28
# 2015-01-16    11.49
# 2015-01-15    11.01
# 2015-01-14    11.13
# 2015-01-13    11.03
# 2015-01-12    11.18
# 2015-01-09    11.71
# 2015-01-08    11.92
# 2015-01-07    11.99
# 2015-01-06    11.66
# 2015-01-05    11.39
# 2014-12-31    11.26
# 2014-12-30    11.13
# ...

# %%
stock[0:5] #取出列
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#       <th>volume</th>
#       <th>price_change</th>
#       <th>p_change</th>
#       <th>ma5</th>
#       <th>ma10</th>
#       <th>ma20</th>
#       <th>v_ma5</th>
#       <th>v_ma10</th>
#       <th>v_ma20</th>
#       <th>turnover</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
# ...

# %%
stock["open"][0:5] #查看前五行的开盘价
# Out:
# date
# 2017-11-28    24.01
# 2017-11-27    24.40
# 2017-11-24    24.10
# 2017-11-23    25.30
# 2017-11-22    25.21
# Name: open, dtype: float64

# %%
stock[0:5] ["open"] #等价
# Out:
# date
# 2017-11-28    24.01
# 2017-11-27    24.40
# 2017-11-24    24.10
# 2017-11-23    25.30
# 2017-11-22    25.21
# Name: open, dtype: float64

# %%
stock.head(5)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#       <th>volume</th>
#       <th>price_change</th>
#       <th>p_change</th>
#       <th>ma5</th>
#       <th>ma10</th>
#       <th>ma20</th>
#       <th>v_ma5</th>
#       <th>v_ma10</th>
#       <th>v_ma20</th>
#       <th>turnover</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
# ...

# %%
stock[["open","high","close","low"]][0:5] #选择其中某几列
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-11-28</th>
#       <td>24.01</td>
#       <td>24.90</td>
#       <td>24.70</td>
#       <td>24.00</td>
#     </tr>
#     <tr>
#       <th>2017-11-27</th>
#       <td>24.40</td>
#       <td>24.95</td>
#       <td>24.21</td>
#       <td>24.01</td>
#     </tr>
#     <tr>
#       <th>2017-11-24</th>
#       <td>24.10</td>
#       <td>24.70</td>
#       <td>24.45</td>
# ...

# %%
stock["open"].value_counts() #计次,排序，
# Out:
# 21.30    6
# 20.85    6
# 24.10    5
# 22.20    5
# 22.60    4
# 21.61    4
# 21.90    4
# 21.00    4
# 15.50    4
# 21.14    4
# 20.55    3
# 22.30    3
# 29.30    3
# 20.38    3
# 21.80    3
# 22.41    3
# 23.45    3
# 21.79    3
# 19.60    3
# 21.82    3
# 17.85    3
# 21.88    3
# 21.45    3
# 21.21    3
# 19.35    3
# 28.00    3
# 18.50    3
# 21.60    3
# 21.10    3
# 22.50    3
#         ..
# 28.88    1
# 27.12    1
# 16.94    1
# 21.93    1
# 21.99    1
# 27.86    1
# 19.40    1
# 11.99    1
# 14.86    1
# 17.20    1
# 22.52    1
# 16.96    1
# 22.64    1
# 26.58    1
# 22.17    1
# 17.98    1
# 15.55    1
# 23.78    1
# 22.28    1
# 20.91    1
# 19.48    1
# 12.64    1
# 18.88    1
# 20.84    1
# 21.46    1
# 23.93    1
# 21.17    1
# 17.82    1
# 23.16    1
# 18.67    1
# Name: open, Length: 483, dtype: int64

# %%
high=stock["high"].value_counts() #计次,排序，

# %%
type(high) #pandas.core.series.Series
# Out:
# pandas.core.series.Series

# %%
high
# Out:
# 21.00    4
# 19.50    4
# 19.90    3
# 21.30    3
# 21.97    3
# 22.78    3
# 22.20    3
# 16.50    3
# 21.49    3
# 22.38    3
# 11.13    3
# 28.50    3
# 23.65    3
# 24.45    3
# 21.38    3
# 21.70    3
# 22.40    3
# 22.66    3
# 21.98    3
# 21.87    3
# 18.50    3
# 22.30    3
# 18.80    3
# 12.15    3
# 21.80    3
# 15.35    2
# 17.99    2
# 21.99    2
# 21.40    2
# 19.89    2
#         ..
# 19.60    1
# 14.65    1
# 29.62    1
# 28.72    1
# 11.92    1
# 13.60    1
# 18.36    1
# 29.37    1
# 16.48    1
# 22.44    1
# 15.66    1
# 20.43    1
# 18.24    1
# 12.18    1
# 19.70    1
# 25.52    1
# 20.18    1
# 20.34    1
# 20.35    1
# 17.35    1
# 17.24    1
# 18.06    1
# 17.29    1
# 18.73    1
# 13.38    1
# 24.56    1
# 21.29    1
# 22.82    1
# 14.53    1
# 28.75    1
# Name: high, Length: 501, dtype: int64

# %%
type(high)
# Out:
# pandas.core.series.Series

# %%
type(stock)
# Out:
# pandas.core.frame.DataFrame

# %%
high.index
# Out:
# Float64Index([ 21.0,  19.5,  19.9,  21.3, 21.97, 22.78,  22.2,  16.5, 21.49, 22.38,
#               ...
#               17.24, 18.06, 17.29, 18.73, 13.38, 24.56, 21.29, 22.82, 14.53, 28.75], dtype='float64', length=501)
