# %%
import numpy as np
import pandas as pd

# %%
A=pd.DataFrame(np.random.randint(0,20,(2,2)),columns=list("ab"))
A  #索引一致才能计算，
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16</td>
#       <td>17</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
B=pd.DataFrame(np.random.randint(0,20,(2,2)),columns=list("ab"))
B
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
A+B
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>13</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17</td>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
A=pd.DataFrame(np.random.randint(0,20,(2,2)),columns=list("ab"))
B=pd.DataFrame(np.random.randint(0,20,(2,2)),columns=list("bc"))
A+B  #索引一致才能计算，有一方索引不存在，nan
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>13</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>29</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
A.add(B,fill_value=0)  #索引一致才能计算，有一方索引不存在，nan
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.0</td>
#       <td>13</td>
#       <td>12.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.0</td>
#       <td>29</td>
#       <td>9.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
A  #+- */   **   //
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
B
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>b</th>
#       <th>c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>13</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X=np.random.randint(10,size=(3,4))
X
# Out:
# array([[9, 0, 6, 3],
#        [6, 2, 0, 7],
#        [8, 0, 7, 3]])

# %%
Y=np.random.randint(10,size=(4))
Y
# Out:
# array([2, 9, 7, 9])

# %%
X-Y #列相等计算
# Out:
# array([[ 7, -9, -1, -6],
#        [ 4, -7, -7, -2],
#        [ 6, -9,  0, -6]])

# %%
df=pd.DataFrame(X,columns=list("abcd"))
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9</td>
#       <td>0</td>
#       <td>6</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6</td>
#       <td>2</td>
#       <td>0</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>0</td>
#       <td>7</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.iloc[0,::2] #间隔2
# Out:
# a    9
# d    3
# Name: 0, dtype: int32

# %%
type(df.iloc[0,::2] )
# Out:
# pandas.core.series.Series

# %%
df -df.iloc[0,::2] #不匹配，没有的数据nan
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-3.0</td>
#       <td>NaN</td>
#       <td>-6.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.0</td>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df -df.iloc[0] #匹配，每个进行减法
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-3</td>
#       <td>2</td>
#       <td>-6</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sub(df.iloc[0,::2],axis=1)#1代表行
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-3.0</td>
#       <td>NaN</td>
#       <td>-6.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.0</td>
#       <td>NaN</td>
#       <td>1.0</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sub(df.iloc[0,::2],axis=0)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>a</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>c</th>
# ...

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9</td>
#       <td>0</td>
#       <td>6</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6</td>
#       <td>2</td>
#       <td>0</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8</td>
#       <td>0</td>
#       <td>7</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.sub( pd.Series([100,200,300]),axis=0)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-91</td>
#       <td>-100</td>
#       <td>-94</td>
#       <td>-97</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-194</td>
#       <td>-198</td>
#       <td>-200</td>
#       <td>-193</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-292</td>
#       <td>-300</td>
#       <td>-293</td>
#       <td>-297</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#匹配的情况，都计算，不匹配就是nan  axis=0列  1行
