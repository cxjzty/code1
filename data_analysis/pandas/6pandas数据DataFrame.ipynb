# %%
import numpy as np
import pandas as pd

# %%
import tushare as ts
ts.get_hist_data('600848') #一次性获取全部日k线数据
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#       <th>volume</th>
#       <th>price_change</th>
#       <th>p_change</th>
#       <th>ma5</th>
#       <th>ma10</th>
#       <th>ma20</th>
#       <th>v_ma5</th>
#       <th>v_ma10</th>
#       <th>v_ma20</th>
#       <th>turnover</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
# ...

# %%
type(ts.get_hist_data('600848'))
# Out:
# pandas.core.frame.DataFrame

# %%
columns=["数学","英语","语文","理科综合","文科综合"]
index=["top2","c9","985","211","1本","2本","3本","大专"]
data={"数学":[145,140,135,130,125,120,115,100],
      "英语":[145,140,135,130,125,120,115,100],
      "语文":[145,140,135,130,125,120,115,100],
      "理科综合":[145*2,140*2,135*2,130*2,125*2,120*2,115*2,100]}

# %%
frame=pd.DataFrame(data=data,columns=columns,index=index)
frame #创建数据框架，自定义索引
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>英语</th>
#       <th>语文</th>
#       <th>理科综合</th>
#       <th>文科综合</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>top2</th>
#       <td>145</td>
#       <td>145</td>
#       <td>145</td>
#       <td>290</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>c9</th>
#       <td>140</td>
#       <td>140</td>
#       <td>140</td>
#       <td>280</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>985</th>
#       <td>135</td>
#       <td>135</td>
#       <td>135</td>
#       <td>270</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>211</th>
#       <td>130</td>
# ...

# %%
frame.values #数值，numpy二维数组
# Out:
# array([[145, 145, 145, 290, nan],
#        [140, 140, 140, 280, nan],
#        [135, 135, 135, 270, nan],
#        [130, 130, 130, 260, nan],
#        [125, 125, 125, 250, nan],
#        [120, 120, 120, 240, nan],
#        [115, 115, 115, 230, nan],
#        [100, 100, 100, 100, nan]], dtype=object)

# %%
frame.columns #列
# Out:
# Index(['数学', '英语', '语文', '理科综合', '文科综合'], dtype='object')

# %%
frame.shape #形状
# Out:
# (8, 5)

# %%
frame.size #大小
# Out:
# 40

# %%
columns=["数学","英语","语文","理科综合","文科综合"]
data={"数学":[145,140,135,130,125,120,115,100],
      "英语":[145,140,135,130,125,120,115,100],
      "语文":[145,140,135,130,125,120,115,100],
      "理科综合":[145*2,140*2,135*2,130*2,125*2,120*2,115*2,100]}
frame=pd.DataFrame(data=data,columns=columns)
frame #创建数据框架，默认数字索引
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>英语</th>
#       <th>语文</th>
#       <th>理科综合</th>
#       <th>文科综合</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>145</td>
#       <td>145</td>
#       <td>145</td>
#       <td>290</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>140</td>
#       <td>140</td>
#       <td>140</td>
#       <td>280</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>135</td>
#       <td>135</td>
#       <td>135</td>
#       <td>270</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>130</td>
# ...

# %%
frame["数学"]
# Out:
# 0    145
# 1    140
# 2    135
# 3    130
# 4    125
# 5    120
# 6    115
# 7    100
# Name: 数学, dtype: int64

# %%
frame.数学
# Out:
# 0    145
# 1    140
# 2    135
# 3    130
# 4    125
# 5    120
# 6    115
# 7    100
# Name: 数学, dtype: int64

# %%
print(type(frame.数学),type(frame["数学"]))
# Out:
# <class 'pandas.core.series.Series'> <class 'pandas.core.series.Series'>

# %%
frame.ix[0] #数字索引情况下，取出第一行
# Out:
# c:\users\tsinghua-yincheng\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 数学      145
# 英语      145
# 语文      145
# 理科综合    290
# 文科综合    NaN
# Name: 0, dtype: object

# %%
type(frame.ix[0]) #取出行的办法
# Out:
# pandas.core.series.Series

# %%
frame.loc[0] #取出行的办法
# Out:
# 数学      145
# 英语      145
# 语文      145
# 理科综合    290
# 文科综合    NaN
# Name: 0, dtype: object

# %%
frame.iloc[0]   #取出行的办法
# Out:
# 数学      145
# 英语      145
# 语文      145
# 理科综合    290
# 文科综合    NaN
# Name: 0, dtype: object

# %%
frame["数学"][0] #取出元素的办法
# Out:
# 145

# %%
frame.数学[0]   #取出元素的办法
# Out:
# 145

# %%
frame.iloc[0][0]   #取出元素的办法
# Out:
# 145

# %%
frame[["数学","语文"]] #取出多列
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>语文</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>145</td>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>140</td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>135</td>
#       <td>135</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>130</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>125</td>
#       <td>125</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>120</td>
#       <td>120</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>115</td>
# ...

# %%
type(frame[["数学","语文"]] ) #一维数组series,2维dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
frame.ix[0:3] #取出多行
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>英语</th>
#       <th>语文</th>
#       <th>理科综合</th>
#       <th>文科综合</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>145</td>
#       <td>145</td>
#       <td>145</td>
#       <td>290</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>140</td>
#       <td>140</td>
#       <td>140</td>
#       <td>280</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>135</td>
#       <td>135</td>
#       <td>135</td>
#       <td>270</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>130</td>
# ...

# %%
type(frame.ix[0:3])#一维数组series,2维dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
frame.loc[0:3] #取出多行  0-3 包含3
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>英语</th>
#       <th>语文</th>
#       <th>理科综合</th>
#       <th>文科综合</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>145</td>
#       <td>145</td>
#       <td>145</td>
#       <td>290</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>140</td>
#       <td>140</td>
#       <td>140</td>
#       <td>280</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>135</td>
#       <td>135</td>
#       <td>135</td>
#       <td>270</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>130</td>
# ...

# %%
frame.iloc[0:3]#取出多行
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>英语</th>
#       <th>语文</th>
#       <th>理科综合</th>
#       <th>文科综合</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>145</td>
#       <td>145</td>
#       <td>145</td>
#       <td>290</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>140</td>
#       <td>140</td>
#       <td>140</td>
#       <td>280</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>135</td>
#       <td>135</td>
#       <td>135</td>
#       <td>270</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame[0:3]#取出多行
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>英语</th>
#       <th>语文</th>
#       <th>理科综合</th>
#       <th>文科综合</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>145</td>
#       <td>145</td>
#       <td>145</td>
#       <td>290</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>140</td>
#       <td>140</td>
#       <td>140</td>
#       <td>280</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>135</td>
#       <td>135</td>
#       <td>135</td>
#       <td>270</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame[["数学","语文"]][0:3] #取出多行多列
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>语文</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>145</td>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>140</td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>135</td>
#       <td>135</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
columns=["数学","英语","语文","理科综合","文科综合"]
index=["top2","c9","985","211","1本","2本","3本","大专"]
data={"数学":[145,140,135,130,125,120,115,100],
      "英语":[145,140,135,130,125,120,115,100],
      "语文":[145,140,135,130,125,120,115,100],
      "理科综合":[145*2,140*2,135*2,130*2,125*2,120*2,115*2,100]}
frame=pd.DataFrame(data=data,columns=columns,index=index)
frame #创建数据框架，自定义索引
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>英语</th>
#       <th>语文</th>
#       <th>理科综合</th>
#       <th>文科综合</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>top2</th>
#       <td>145</td>
#       <td>145</td>
#       <td>145</td>
#       <td>290</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>c9</th>
#       <td>140</td>
#       <td>140</td>
#       <td>140</td>
#       <td>280</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>985</th>
#       <td>135</td>
#       <td>135</td>
#       <td>135</td>
#       <td>270</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>211</th>
#       <td>130</td>
# ...

# %%
#单行，单列，单个元素，多行，多列，多行多列

# %%
frame.ix["985"] #单行
# Out:
# c:\users\tsinghua-yincheng\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 数学      135
# 英语      135
# 语文      135
# 理科综合    270
# 文科综合    NaN
# Name: 985, dtype: object

# %%
frame.loc["985"]  #单行
# Out:
# 数学      135
# 英语      135
# 语文      135
# 理科综合    270
# 文科综合    NaN
# Name: 985, dtype: object

# %%
frame.iloc[2]  #单行
# Out:
# 数学      135
# 英语      135
# 语文      135
# 理科综合    270
# 文科综合    NaN
# Name: 985, dtype: object

# %%
frame["数学"] #单列
# Out:
# top2    145
# c9      140
# 985     135
# 211     130
# 1本      125
# 2本      120
# 3本      115
# 大专      100
# Name: 数学, dtype: int64

# %%
frame.数学  #单列
# Out:
# top2    145
# c9      140
# 985     135
# 211     130
# 1本      125
# 2本      120
# 3本      115
# 大专      100
# Name: 数学, dtype: int64

# %%
frame.数学["211"] #单个元素
# Out:
# 130

# %%
frame["数学"]["211"] #单个元素
# Out:
# 130

# %%
frame.ix["211"]["数学"]#单个元素
# Out:
# 130

# %%
frame.iloc[3][0] #[3]行  0第一个数学 #单个元素
# Out:
# 130

# %%
frame[["数学","语文"]] #多列
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>语文</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>top2</th>
#       <td>145</td>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>c9</th>
#       <td>140</td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>985</th>
#       <td>135</td>
#       <td>135</td>
#     </tr>
#     <tr>
#       <th>211</th>
#       <td>130</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>1本</th>
#       <td>125</td>
#       <td>125</td>
#     </tr>
#     <tr>
#       <th>2本</th>
#       <td>120</td>
#       <td>120</td>
#     </tr>
#     <tr>
#       <th>3本</th>
#       <td>115</td>
# ...

# %%
frame.ix[["top2","c9"]] #取出多行
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>英语</th>
#       <th>语文</th>
#       <th>理科综合</th>
#       <th>文科综合</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>top2</th>
#       <td>145</td>
#       <td>145</td>
#       <td>145</td>
#       <td>290</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>c9</th>
#       <td>140</td>
#       <td>140</td>
#       <td>140</td>
#       <td>280</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.loc[["top2","c9"]]#取出多行
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>英语</th>
#       <th>语文</th>
#       <th>理科综合</th>
#       <th>文科综合</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>top2</th>
#       <td>145</td>
#       <td>145</td>
#       <td>145</td>
#       <td>290</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>c9</th>
#       <td>140</td>
#       <td>140</td>
#       <td>140</td>
#       <td>280</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.iloc[0:2]#取出多行
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>英语</th>
#       <th>语文</th>
#       <th>理科综合</th>
#       <th>文科综合</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>top2</th>
#       <td>145</td>
#       <td>145</td>
#       <td>145</td>
#       <td>290</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>c9</th>
#       <td>140</td>
#       <td>140</td>
#       <td>140</td>
#       <td>280</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame[["数学","语文"]][0:3]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>语文</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>top2</th>
#       <td>145</td>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>c9</th>
#       <td>140</td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>985</th>
#       <td>135</td>
#       <td>135</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame[["数学","语文"]].loc[["top2","c9"]]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>语文</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>top2</th>
#       <td>145</td>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>c9</th>
#       <td>140</td>
#       <td>140</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame[["数学","语文"]].iloc[0:2]#取出多行
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>语文</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>top2</th>
#       <td>145</td>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>c9</th>
#       <td>140</td>
#       <td>140</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame[["数学","语文"]].ix[["top2","c9"]] #取出多行
# Out:
# c:\users\tsinghua-yincheng\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>数学</th>
#       <th>语文</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>top2</th>
#       <td>145</td>
#       <td>145</td>
#     </tr>
#     <tr>
#       <th>c9</th>
#       <td>140</td>
#       <td>140</td>
# ...
